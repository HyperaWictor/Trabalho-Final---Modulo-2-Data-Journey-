# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("EDA_Industrializados_202110.csv", sep=";", encoding="latin1")

# %%
df
# Out:
#          ANO_VENDA  MES_VENDA UF_VENDA        MUNICIPIO_VENDA  \
# 0             2021         10       SP       IGARAÇU DO TIETÊ
# 1             2021         10       SP       IGARAÇU DO TIETÊ
# 2             2021         10       SP       IGARAÇU DO TIETÊ
# 3             2021         10       SP       IGARAÇU DO TIETÊ
# 4             2021         10       SP       IGARAÇU DO TIETÊ
# ...            ...        ...      ...                    ...
# 5989703       2021         10       SP  SÃO JOSÉ DO RIO PRETO
# 5989704       2021         10       SP  SÃO JOSÉ DO RIO PRETO
# 5989705       2021         10       SP  SÃO JOSÉ DO RIO PRETO
# 5989706       2021         10       SP  SÃO JOSÉ DO RIO PRETO
# 5989707       2021         10       SP  SÃO JOSÉ DO RIO PRETO
#
#                      PRINCIPIO_ATIVO  \
# 0                         CELECOXIBE
# 1                         CELECOXIBE
# 2                         CELECOXIBE
# 3                         CELECOXIBE
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5989708 entries, 0 to 5989707
# Data columns (total 15 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   ANO_VENDA               int64
#  1   MES_VENDA               int64
#  2   UF_VENDA                object
#  3   MUNICIPIO_VENDA         object
#  4   PRINCIPIO_ATIVO         object
#  5   DESCRICAO_APRESENTACAO  object
#  6   QTD_VENDIDA             int64
#  7   UNIDADE_MEDIDA          object
#  8   CONSELHO_PRESCRITOR     object
#  9   UF_CONSELHO_PRESCRITOR  object
#  10  TIPO_RECEITUARIO        float64
#  11  CID10                   object
#  12  SEXO                    float64
#  13  IDADE                   float64
#  14  UNIDADE_IDADE           float64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 685.5+ MB

# %%
df.groupby(["UF_VENDA", "PRINCIPIO_ATIVO"]).count()
# Out:
#                                                              MUNICIPIO_VENDA  \
# UF_VENDA PRINCIPIO_ATIVO
# AC       ACETATO DE PREDNISOLONA + GATIFLOXACINO SESQUI-...                5
#          ACETATO DE RETINOL + AMINOÁCIDOS + CLORANFENICO...               73
#          ACETATO DE ZUCLOPENTIXOL                                          1
#          ACETONIDA DE TRIANCINOLONA + GRAMICIDINA + NIST...                8
#          ADAPALENO                                                         1
# ...                                                                      ...
# TO       ÁCIDO CLAVULÂNICO + AMOXICILINA TRIHIDRATADA                     19
#          ÁCIDO FUSÍDICO                                                   30
#          ÁCIDO FUSÍDICO + VALERATO DE BETAMETASONA                        39
#          ÁCIDO VALPRÓICO                                                  57
#          ÁCIDO VALPRÓICO + VALPROATO DE SÓDIO                            134
#
# ...

# %%
df
# Out:
#         UF_VENDA        MUNICIPIO_VENDA              PRINCIPIO_ATIVO  \
# 0             SP       IGARAÇU DO TIETÊ                   CELECOXIBE
# 1             SP       IGARAÇU DO TIETÊ                   CELECOXIBE
# 2             SP       IGARAÇU DO TIETÊ                   CELECOXIBE
# 3             SP       IGARAÇU DO TIETÊ                   CELECOXIBE
# 4             SP       IGARAÇU DO TIETÊ                   CELECOXIBE
# ...          ...                    ...                          ...
# 5989703       SP  SÃO JOSÉ DO RIO PRETO  CLORIDRATO DE MOXIFLOXACINO
# 5989704       SP  SÃO JOSÉ DO RIO PRETO  CLORIDRATO DE MOXIFLOXACINO
# 5989705       SP  SÃO JOSÉ DO RIO PRETO  CLORIDRATO DE MOXIFLOXACINO
# 5989706       SP  SÃO JOSÉ DO RIO PRETO  CLORIDRATO DE MOXIFLOXACINO
# 5989707       SP  SÃO JOSÉ DO RIO PRETO  CLORIDRATO DE MOXIFLOXACINO
#
#                                     DESCRICAO_APRESENTACAO  QTD_VENDIDA  \
# ...

# %%
df.loc[df["UF_VENDA"] == "GO"]["PRINCIPIO_ATIVO"].value_counts()
# Out:
# AZITROMICINA DI-HIDRATADA                              15990
# AMOXICILINA TRI-HIDRATADA + CLAVULANATO DE POTÁSSIO    10955
# AMOXICILINA TRI-HIDRATADA                               9373
# AMOXICILINA + CLAVULANATO DE POTÁSSIO                   7652
# AMOXICILINA                                             6876
#                                                        ...
# TARTARATO DE BRIMONIDINA                                   1
# SINVASTATINA                                               1
# ANFOTERICINA B + TETRACICLINA                              1
# CLORIDRATO DE DAUNORRUBICINA                               1
# PASSIFLORA INCARNATA L.                                    1
# Name: PRINCIPIO_ATIVO, Length: 400, dtype: int64
