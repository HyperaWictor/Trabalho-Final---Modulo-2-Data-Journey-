# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("EDA_Industrializados_202110.csv", sep=";", encoding="latin1")

# %%
df
# Out:
#          ANO_VENDA  MES_VENDA UF_VENDA        MUNICIPIO_VENDA  \
# 0             2021         10       SP       IGARAÇU DO TIETÊ
# 1             2021         10       SP       IGARAÇU DO TIETÊ
# 2             2021         10       SP       IGARAÇU DO TIETÊ
# 3             2021         10       SP       IGARAÇU DO TIETÊ
# 4             2021         10       SP       IGARAÇU DO TIETÊ
# ...            ...        ...      ...                    ...
# 5989703       2021         10       SP  SÃO JOSÉ DO RIO PRETO
# 5989704       2021         10       SP  SÃO JOSÉ DO RIO PRETO
# 5989705       2021         10       SP  SÃO JOSÉ DO RIO PRETO
# 5989706       2021         10       SP  SÃO JOSÉ DO RIO PRETO
# 5989707       2021         10       SP  SÃO JOSÉ DO RIO PRETO
#
#                      PRINCIPIO_ATIVO  \
# 0                         CELECOXIBE
# 1                         CELECOXIBE
# 2                         CELECOXIBE
# 3                         CELECOXIBE
# ...

# %%
df.loc[df["UF_VENDA"] == "TO"][df["MUNICIPIO_VENDA"] == "TAGUATINGA"].value_counts()
# Out:
# C:\Users\diullio.santos\AppData\Local\Temp\ipykernel_4892\2211666792.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.loc[df["UF_VENDA"] == "TO"][df["MUNICIPIO_VENDA"] == "TAGUATINGA"].value_counts()
# Series([], dtype: int64)

# %%
x = df.groupby(["UF_VENDA", "PRINCIPIO_ATIVO", "MUNICIPIO_VENDA"]).count()

# %%
x
# Out:
#                                                                                      DESCRICAO_APRESENTACAO  \
# UF_VENDA PRINCIPIO_ATIVO                                    MUNICIPIO_VENDA
# AC       ACETATO DE PREDNISOLONA + GATIFLOXACINO SESQUI-... RIO BRANCO                                    5
#          ACETATO DE RETINOL + AMINOÁCIDOS + CLORANFENICO... CRUZEIRO DO SUL                               2
#                                                             EPITACIOLÂNDIA                                1
#                                                             RIO BRANCO                                   69
#                                                             SENA MADUREIRA                                1
# ...                                                                                                     ...
# TO       ÁCIDO VALPRÓICO + VALPROATO DE SÓDIO               PRAIA NORTE                                   3
# ...

# %%
filtro = df.loc[(df['UF_VENDA'] == "TO") & (df['MUNICIPIO_VENDA'] == "TAGUATINGA")]

# %%
soma = filtro.groupby("PRINCIPIO_ATIVO").sum()

# %%
soma
# Out:
#                                        QTD_VENDIDA  TIPO_RECEITUARIO  SEXO  \
# PRINCIPIO_ATIVO
# AGOMELATINA                                      1               1.0   0.0
# ALPRAZOLAM                                      15              10.0   0.0
# AMOXICILINA                                      4              15.0   4.0
# AMOXICILINA + CLAVULANATO DE POTÁSSIO           10              25.0   8.0
# AMOXICILINA TRI-HIDRATADA                        7              35.0  13.0
# ...                                            ...               ...   ...
# SULFAMETOXAZOL + TRIMETOPRIMA                   16              60.0  18.0
# SULFATO DE MORFINA PENTAIDRATADO                 4               4.0   0.0
# TOPIRAMATO                                       6               5.0   0.0
# VALPROATO DE SÓDIO                               8               3.0   0.0
# ÁCIDO VALPRÓICO                                  5               2.0   0.0
#
# ...

# %%
max_soma = soma["QTD_VENDIDA"].max()

# %%
max_soma
# Out:
# 56

# %%
indice_max = soma["QTD_VENDIDA"].idxmax()

# %%
indice_max
# Out:
# 'CARBAMAZEPINA'

# %%
df.filter(["UF_VENDA","MUNICIPIO_VENDA", "PRINCIPIO_ATIVO", "QTD_VENDIDA"])
# Out:
#         UF_VENDA        MUNICIPIO_VENDA              PRINCIPIO_ATIVO  \
# 0             SP       IGARAÇU DO TIETÊ                   CELECOXIBE
# 1             SP       IGARAÇU DO TIETÊ                   CELECOXIBE
# 2             SP       IGARAÇU DO TIETÊ                   CELECOXIBE
# 3             SP       IGARAÇU DO TIETÊ                   CELECOXIBE
# 4             SP       IGARAÇU DO TIETÊ                   CELECOXIBE
# ...          ...                    ...                          ...
# 5989703       SP  SÃO JOSÉ DO RIO PRETO  CLORIDRATO DE MOXIFLOXACINO
# 5989704       SP  SÃO JOSÉ DO RIO PRETO  CLORIDRATO DE MOXIFLOXACINO
# 5989705       SP  SÃO JOSÉ DO RIO PRETO  CLORIDRATO DE MOXIFLOXACINO
# 5989706       SP  SÃO JOSÉ DO RIO PRETO  CLORIDRATO DE MOXIFLOXACINO
# 5989707       SP  SÃO JOSÉ DO RIO PRETO  CLORIDRATO DE MOXIFLOXACINO
#
#          QTD_VENDIDA
# 0                 14
# 1                  1
# 2                  3
# 3                  1
# 4                  3
# ...

# %%
df.loc[df["UF_VENDA"] == "TO"][df["MUNICIPIO_VENDA"] == "TAGUATINGA"]
# Out:
# C:\Users\diullio.santos\AppData\Local\Temp\ipykernel_4892\3679330738.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.loc[df["UF_VENDA"] == "TO"][df["MUNICIPIO_VENDA"] == "TAGUATINGA"]
#        UF_VENDA MUNICIPIO_VENDA     PRINCIPIO_ATIVO  \
# 351326       TO      TAGUATINGA         AGOMELATINA
# 351327       TO      TAGUATINGA          ALPRAZOLAM
# 351328       TO      TAGUATINGA          ALPRAZOLAM
# 351329       TO      TAGUATINGA          ALPRAZOLAM
# 351330       TO      TAGUATINGA          ALPRAZOLAM
# ...         ...             ...                 ...
# 365466       TO      TAGUATINGA  VALPROATO DE SÓDIO
# 365467       TO      TAGUATINGA  VALPROATO DE SÓDIO
# 365468       TO      TAGUATINGA  VALPROATO DE SÓDIO
# 365469       TO      TAGUATINGA     ÁCIDO VALPRÓICO
# 365470       TO      TAGUATINGA     ÁCIDO VALPRÓICO
#
#                             DESCRICAO_APRESENTACAO  QTD_VENDIDA  \
# ...

# %%
df.loc[df["UF_VENDA"] == "TO"]["PRINCIPIO_ATIVO"].value_counts()
# Out:
# AZITROMICINA DI-HIDRATADA                                            2719
# AMOXICILINA TRI-HIDRATADA                                            1766
# CEFALEXINA                                                           1229
# CEFALEXINA MONOIDRATADA                                              1187
# AMOXICILINA TRI-HIDRATADA + CLAVULANATO DE POTÁSSIO                  1168
#                                                                      ...
# CETOCONAZOL + DIPROPIONATO DE BETAMETASONA + SULFATO DE NEOMICINA       1
# ETABONATO DE LOTEPREDNOL + TOBRAMICINA                                  1
# CLORIDRATO DE LOPERAMIDA                                                1
# ETOSSUXIMIDA                                                            1
# AMISSULPRIDA                                                            1
# Name: PRINCIPIO_ATIVO, Length: 261, dtype: int64
